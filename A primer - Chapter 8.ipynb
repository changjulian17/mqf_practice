# %% [markdown]
# # Question 3

# %%
import numpy as np

# %%
B = 100 + 1/32
n = 10
c = 3.375
x0 = .1
tol = 1e-6

t = [x*.5 for x in range(1,n+1)]
v = [c/2 for x in range(n)]
v[n-1] += 100

# %%
def newton(x, t, v, B):
    num_sum = 0
    den_sum = 0
    
    for a, b in zip(t,v):
        # print(b, b*np.exp(-x*a))
        num_sum += b*np.exp(-x*a)
    num_sum -= B
        
    for c, d in zip(t,v):
        # print(d, c*d*np.exp(-x*c))
        den_sum += c*d*np.exp(-x*c)
    
    x_new = x + num_sum / den_sum
    
    
    return x_new

# %%
x_new = x0
x_old = x0-1
while np.abs(x_new-x_old) > tol:
    x_old = x_new
    x_new = newton(x_old, t, v, B)
    print(x_old, x_new)
# Out:
# 0.1 0.021397014741595874
# 0.021397014741595874 0.033057328860338325
# 0.033057328860338325 0.03340081140223473
# 0.03340081140223473 0.03340109853803073

# %%
D = 0 
C = 0

for c, d in zip(t,v):
    # print(d, c*d*np.exp(-x*c))
    D += c*d*np.exp(-x_new*c)
    C += c**2*d*np.exp(-x_new*c)
    
D /= B
C /= B

print(f"Yield: {x_new*100:1f}%")
print(f"Duration: {D}")
print(f"Convexity: {C}")
# Out:
# Yield: 3.340110%
# Duration: 4.642735048429879
# Convexity: 22.573118015872677

# %% [markdown]
# # Question 5

# %%
norm.cdf(1)
# Out:
# 0.8413447460685429

# %%
from scipy.stats import norm

tol = 1e-7

def fxn(x):
    T = .25
    K = 30
    S = 30
    q = .02
    C = 2.5
    r = .06
    
    d1 = (np.log(S/K)+(r-q+.5*x**2)*T)/(x*np.sqrt(T))
    d2 = d1 - x*np.sqrt(T)
    
    C_approx = S*np.exp(-q*T)*norm.cdf(d1)-K*np.exp(-r*T)*norm.cdf(d2)
    delta = C-C_approx
    
    return delta

# %%
# Bisection method
a, b = .0001, 1
tol_int = tol
tol_approx = tol

def bisect(a, b, tol_int, tol_approx):
    x_l = a
    x_r = b
    i = 0 
    
    while max(abs(fxn(x_l)),abs(fxn(x_r))) > tol_approx or (x_r-x_l)>tol_int:
        x_m = (x_l + x_r)/2
        print(f"{i} || ", x_l, x_r)
        if fxn(x_l)*fxn(x_m) < 0:
            x_r = x_m
        else:
            x_l = x_m
        i += 1
    
    return x_m

# %%
bisect(a, b, tol_int, tol_approx)
# Out:
# 0 ||  0.0001 1
# 1 ||  0.0001 0.50005
# 2 ||  0.250075 0.50005
# 3 ||  0.37506249999999997 0.50005
# 4 ||  0.37506249999999997 0.43755625
# 5 ||  0.37506249999999997 0.406309375
# 6 ||  0.39068593749999997 0.406309375
# 7 ||  0.39068593749999997 0.39849765625
# 8 ||  0.394591796875 0.39849765625
# 9 ||  0.3965447265625 0.39849765625
# 10 ||  0.3965447265625 0.39752119140625
# 11 ||  0.39703295898437496 0.39752119140625
# 12 ||  0.39703295898437496 0.39727707519531247
# 13 ||  0.39703295898437496 0.3971550170898437
# 14 ||  0.39703295898437496 0.3970939880371093
# 15 ||  0.39703295898437496 0.3970634735107421
# 16 ||  0.39704821624755854 0.3970634735107421
# 17 ||  0.39704821624755854 0.39705584487915035
# 18 ||  0.39704821624755854 0.3970520305633545
# 19 ||  0.39704821624755854 0.39705012340545653
# 20 ||  0.39704821624755854 0.3970491698265075
# 21 ||  0.39704821624755854 0.39704869303703305
# 22 ||  0.39704845464229577 0.39704869303703305
# 23 ||  0.3970485738396644 0.39704869303703305
# 24 ||  0.3970485738396644 0.39704863343834873
# 25 ||  0.39704860363900657 0.39704863343834873
# 0.3970486185386777

# %%
# Newton method
x0 = .5
tol_consec = tol

def d_fxn(x):
    T = .25
    K = 30
    S = 30
    q = .02
    C = 2.5
    r = .06
    
    d1 = (np.log(S/K)+(r-q+.5*x**2)*T)/(x*np.sqrt(T))
    
    y = -S*np.exp(-q*T)*np.sqrt(T/2/np.pi)*np.exp(-.5*d1**2)
    
    return y

def newton1(x0, tol_consec):
    x_new = x0
    x_old = 0
    i = 0
    
    while abs(fxn(x_new)) > tol_approx or abs(x_new-x_old) > tol_consec:

        x_old = x_new
        x_new = x_old - (fxn(x_old) / d_fxn(x_old))
        print(f"{i} || ", x_old, x_new,fxn(x_old),d_fxn(x_old))

        
        i+=1
        
    return x_new

# %%
newton1(x0, tol_consec)
# Out:
# 0 ||  0.5 0.39691563052053713 -0.6054953855003937 -5.873784634449595
# 1 ||  0.39691563052053713 0.39704862856860385 0.0007830945397895306 -5.888015284228571
# 2 ||  0.39704862856860385 0.39704862873147384 9.58978674248101e-10 -5.888000861400251
# 0.39704862873147384

# %%
# Secant Method
x_1, x0 = .6, .5

def secant(x0, x_1):
    x_new = x0
    x_old = x_1
    i = 0
    
    while abs(fxn(x_new))>tol_approx or abs(x_new-x_old)>tol_consec:
        x_oldest = x_old
        x_old = x_new
        x_new = x_old - fxn(x_old)*(x_old-x_oldest)/(fxn(x_old)-fxn(x_oldest))
        print(f"{i} || ", x_old, x_new)
        
        i += 1
        
    return x_new

# %%
secant(x0, x_1)
# Out:
# 0 ||  0.5 0.3967574905209847
# 1 ||  0.3967574905209847 0.3970489566893094
# 2 ||  0.3970489566893094 0.3970486287323524
# 3 ||  0.3970486287323524 0.3970486287314739
# 0.3970486287314739

# %%
fxn(0.3970486287314739)
# Out:
# -3.552713678800501e-15

# %%
# (ii) sig,approx
T = .25
K = 30
S = 30
q = .02
C = 2.5
r = .06
sig_approx = np.sqrt(2*np.pi/T)/S*(C-(r-q)*T*S/2)/(1-(r+q)*T/2)
sig_imp = newton1(x0, tol_consec)
# Out:
# 0 ||  0.5 0.39691563052053713 -0.6054953855003937 -5.873784634449595
# 1 ||  0.39691563052053713 0.39704862856860385 0.0007830945397895306 -5.888015284228571
# 2 ||  0.39704862856860385 0.39704862873147384 9.58978674248101e-10 -5.888000861400251

# %%
rel_error = abs(sig_approx - sig_imp)/sig_imp
sig_approx, sig_imp, f"{rel_error*100:1f}% error"
# Out:
# (0.39667181450389566, 0.39704862873147384, '0.094904% error')

# %% [markdown]
# # Question 6

# %%
x01, x02 = np.array([1.0, 2.0, 3.0]), np.array([2.0, 2.0, 2.0])
tol_approx = 1e-9
tol_consec = 1e-6
h = 1e-6

def f (x):
    x1, x2, x3 = x
    
    y1 = x1**3 + 2*x1*x2 + x3**2 - x2*x3 + 9
    y2 = 2*x1**2 + 2*x1*x2**2 + (x2**3)*x3**2 - (x2**2)*x3 - 2
    y3 = x1*x2*x3 + x1**3 - x3**2 - x1*x2**2 - 4
    
    return np.array([y1, y2, y3])

f(x01), f(x02)
# Out:
# (array([ 17.,  68., -10.]), array([25., 46.,  0.]))

# %%
x01
# Out:
# array([1., 2., 3.])

# %%
def d_f(x,h):

    a = []

    for j in range(3):

        x_addh = np.copy(x)
        x_minh = np.copy(x)

        x_addh[j] = x[j] + h
        x_minh[j] = x[j] - h
        diff = (f(x_addh)-f(x_minh))/h/2
        a.append(diff)

    D_f = np.array(a).T

    return D_f

d_f(x01,h)
# Out:
# array([[  7.        ,  -1.        ,   4.        ],
#        [ 12.        , 104.00000001,  44.        ],
#        [  5.        ,  -1.        ,  -4.        ]])

# %%
x_new = x01
x_old = x01 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_f(x_old, h)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [1. 2. 3.]
# 2  || [ 0.5464  2.7784 -0.2616]
# 3  || [-2.45415693  7.13392935 -0.4031109 ]
# 4  || [-1.59789098  4.85550587 -0.37855094]
# 5  || [-1.42550577  3.00500187 -0.45121636]
# 6  || [-1.62369253  1.99376511 -0.67567152]
# 7  || [-1.69598454  1.97436714 -0.90336961]
# 8  || [-1.69054198  1.98302968 -0.88451335]
# 9  || [-1.69055076  1.98310724 -0.88455808]
# array([-1.69055076,  1.98310724, -0.88455808])

# %%
x_new = x02
x_old = x02 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_f(x_old, h)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [2. 2. 2.]
# 2  || [-0.4516129  -5.35483869 16.4677419 ]
# 3  || [ 0.21571499 -5.66418296  6.75906942]
# 4  || [ 0.28602268 -6.52533236  1.79625249]
# 5  || [ -0.25842516 -12.48640204  -1.61432306]
# 6  || [ -0.08943886 -11.02414741  -1.10705909]
# 7  || [  0.72871719 -46.46471667   4.67295935]
# 8  || [ -1.10342384 -88.17587739  -3.9651133 ]
# 9  || [ -4.72168404  90.39759255 -14.02412573]
# 10  || [ 60.64566488 781.02237103 153.71619169]
# 11  || [ 42.27046492 536.0099644  149.19111457]
# 12  || [ 30.58973798 370.12046226 143.85546861]
# 13  || [ 22.5721879  260.76223431 135.68485105]
# 14  || [ 16.41145583 189.53256405 123.43840749]
# 15  || [ 11.38874445 141.72802987 108.42112572]
# 16  || [  7.17080992 107.94280333  92.98004792]
# 17  || [ 3.2669824  82.65719423 79.16268056]
# 18  || [-3.57932857 60.38586085 71.57901306]
# 19  || [-0.30292736 51.05285038 52.38729463]
# 20  || [ 7.10092715 46.62258054 33.0145512 ]
# 21  || [ 4.17452086 35.05882986 28.79373075]
# 22  || [ 1.69068015 26.05095933 25.49983347]
# 23  || [-9.08582987 11.01096966 34.85339399]
# 24  || [-5.58119137 10.4504102  20.12157435]
# 25  || [-3.25366006  9.43154457 13.03520672]
# 26  || [-1.57926716  8.26506815  8.96562827]
# 27  || [-0.25327703  7.33149803  6.02800881]
# 28  || [1.35886676 7.91061194 2.30755368]
# 29  || [0.39758024 6.17138162 1.95298676]
# 30  || [-0.21288216  5.82988399  1.20377499]
# 31  || [-0.6461537   1.70287303  1.94998401]
# 32  || [-0.83366596  2.52781371  0.37369171]
# 33  || [ 3.02596907 11.27837232  7.73204074]
# 34  || [1.40809667 8.0213023  7.23533422]
# 35  || [-2.53811899  1.87262931 12.02866716]
# 36  || [-1.41061169  1.88333336  6.11751866]
# 37  || [-0.76599037  1.94924685  2.9808878 ]
# 38  || [-0.66317867  2.29352178  1.0699547 ]
# 39  || [-1.00759602  3.27636422  0.85938763]
# 40  || [-0.99608104  3.00507956  0.97994009]
# 41  || [-0.99992034  3.00003259  1.00011561]
# 42  || [-1.          3.00000001  1.00000001]
# array([-1.,  3.,  1.])

# %%
tol_approx, tol_consec
# Out:
# (1e-09, 1e-06)

# %%
# forward differences
def d_ff(x,h):

    a = []

    for j in range(3):

        x_addh = np.copy(x)
        x_minh = np.copy(x)

        x_addh[j] = x[j] + h
#         x_minh[j] = x[j]
        diff = (f(x_addh)-f(x_minh))/h
        a.append(diff)

    D_f = np.array(a).T

    return D_f

d_f(x01,h)
# Out:
# array([[  7.        ,  -1.        ,   4.        ],
#        [ 12.        , 104.00000001,  44.        ],
#        [  5.        ,  -1.        ,  -4.        ]])

# %%
x_new = x01
x_old = x01 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_ff(x_old, h)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [1. 2. 3.]
# 2  || [ 0.54640022  2.77839956 -0.26159934]
# 3  || [-2.45415806  7.13391919 -0.40311904]
# 4  || [-1.59789352  4.85549656 -0.37855891]
# 5  || [-1.42550899  3.00499549 -0.45122396]
# 6  || [-1.62369388  1.99376557 -0.67567635]
# 7  || [-1.6959843   1.97436748 -0.9033686 ]
# 8  || [-1.69054197  1.98302969 -0.88451334]
# 9  || [-1.69055076  1.98310724 -0.88455808]
# array([-1.69055076,  1.98310724, -0.88455808])

# %%
x_new = x02
x_old = x02 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_ff(x_old, h)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [2. 2. 2.]
# 2  || [-0.45161433 -5.35484662 16.46776144]
# 3  || [ 0.21571445 -5.66419144  6.75907765]
# 4  || [ 0.2860225  -6.52534206  1.79625555]
# 5  || [ -0.25842432 -12.48641112  -1.61432047]
# 6  || [ -0.08943811 -11.0241649   -1.10705532]
# 7  || [  0.72874711 -46.46651113   4.67320034]
# 8  || [ -1.10344545 -88.17848269  -3.96519511]
# 9  || [ -4.72184375  90.40289658 -14.02459392]
# 10  || [ 60.66411341 781.25159651 153.76400891]
# 11  || [ 42.28279002 536.17037609 149.23660785]
# 12  || [ 30.59812259 370.2337319  143.89829073]
# 13  || [ 22.57811777 260.8428666  135.72475787]
# 14  || [ 16.41577399 189.5911436  123.47473425]
# 15  || [ 11.39189916 141.77178779 108.45307845]
# 16  || [  7.17311164 107.97629748  93.00725772]
# 17  || [ 3.26881167 82.68340953 79.18511349]
# 18  || [-3.5737987  60.41001598 71.59210709]
# 19  || [-0.29650905 51.07307739 52.39722154]
# 20  || [ 7.14382153 46.6702251  32.97590059]
# 21  || [ 4.20649437 35.09359443 28.76114137]
# 22  || [ 1.72611555 26.08654967 25.4589587 ]
# 23  || [-8.00440935 12.00039946 33.36973013]
# 24  || [-4.82966583 11.25073209 19.84070432]
# 25  || [-2.68145762 10.06168062 13.09301405]
# 26  || [-1.07384493  8.80637252  9.02185595]
# 27  || [0.34021538 7.98242856 5.79659786]
# 28  || [-3.78113754 -0.36512089 12.08887847]
# 29  || [-2.78701284 -0.50598376  5.85740644]
# 30  || [-2.18746071 -0.66344094  2.37076349]
# 31  || [-1.87765575 -1.00379912 -0.39724981]
# 32  || [-3.11249163 -1.95149802  6.72316391]
# 33  || [-2.95408656 -1.93165961  3.27818427]
# 34  || [-2.62676408 -2.09594772  0.85994163]
# 35  || [-2.59258207 -3.62932426 -2.90520069]
# 36  || [-2.95442128 -3.78168329 -1.08661356]
# 37  || [-3.0539293  -3.35602773 -0.29281219]
# 38  || [-3.03924954 -2.52788286  1.28989103]
# 39  || [-2.82440319 -3.08174597 -0.70027035]
# 40  || [-3.0075952  -2.86872626  0.54860031]
# 41  || [-2.875409   -3.93338537 -2.15997123]
# 42  || [-3.05115296 -3.76936656 -0.99513076]
# 43  || [-3.04573987 -3.31245661 -0.21560445]
# 44  || [-3.04674989 -2.31327439  1.74060342]
# 45  || [-2.75554445 -2.77119455 -0.36825306]
# 46  || [-3.00728178 -2.32900206  1.67075508]
# 47  || [-2.75197639 -2.80823227 -0.43029465]
# 48  || [-3.00816136 -2.45463992  1.41002485]
# 49  || [-2.79566926 -2.98990257 -0.61789109]
# 50  || [-3.00731534 -2.76215876  0.76626777]
# 51  || [-2.87024725 -3.55628479 -1.4377713 ]
# 52  || [-3.02672183 -3.40309112 -0.42330233]
# 53  || [-3.03338671 -2.75405674  0.82091687]
# 54  || [-2.87472476 -3.48807128 -1.2930962 ]
# 55  || [-3.02270927 -3.32547428 -0.29324043]
# 56  || [-3.03827622 -2.50707671  1.32553671]
# 57  || [-2.8180105  -3.05562747 -0.67592195]
# 58  || [-3.00702004 -2.83905136  0.60785669]
# 59  || [-2.8758541  -3.80467849 -1.90449368]
# 60  || [-3.04216768 -3.64509132 -0.80874326]
# 61  || [-3.03847334 -3.17012512  0.02998689]
# 62  || [-3.18114247  0.31388043  7.46475647]
# 63  || [-5.23745857 -5.24904758  4.63280784]
# 64  || [-4.37378332 -3.6974757   4.31160365]
# 65  || [-3.75562341 -3.08931359  3.08047892]
# 66  || [-3.27412883 -2.83985398  1.6756148 ]
# 67  || [-2.97196153 -2.95264364  0.2230657 ]
# 68  || [ -2.67101379  -7.77085506 -10.6395937 ]
# 69  || [-2.63962672 -7.47839503 -5.9231136 ]
# 70  || [-4.72068916 -6.67509698 -3.85817081]
# 71  || [-3.76122177 -5.55649331 -2.85527843]
# 72  || [-3.30770179 -4.70967624 -1.99960006]
# 73  || [-3.14013422 -4.06023508 -1.25654806]
# 74  || [-3.06922902 -3.53719587 -0.55032076]
# 75  || [-3.03697009 -2.95066738  0.4501166 ]
# 76  || [-2.87939097 -4.20507769 -2.68069394]
# 77  || [-3.07168604 -4.02342864 -1.35561003]
# 78  || [-3.06531743 -3.55678472 -0.60389855]
# 79  || [-3.03641679 -3.00228671  0.34784171]
# 80  || [-2.8571892  -4.75350564 -3.85111698]
# 81  || [-3.10735377 -4.56519582 -2.06589029]
# 82  || [-3.12141936 -4.01468143 -1.23887273]
# 83  || [-3.06480809 -3.51151768 -0.51906818]
# 84  || [-3.03623668 -2.91090283  0.52494345]
# 85  || [-2.88471486 -3.97364976 -2.20418818]
# 86  || [-3.05434484 -3.79811157 -1.03660275]
# 87  || [-3.04764197 -3.34222075 -0.26508586]
# 88  || [-3.0419652  -2.45971312  1.43323045]
# 89  || [-2.80417017 -2.98015297 -0.5830352 ]
# 90  || [-3.00602486 -2.72432338  0.83828813]
# 91  || [-2.86435017 -3.47138964 -1.29504345]
# 92  || [-3.02219243 -3.320397   -0.28391198]
# 93  || [-3.03898916 -2.48475294  1.37213196]
# 94  || [-2.81135295 -3.02232602 -0.63755534]
# 95  || [-3.00646853 -2.79310618  0.69975732]
# 96  || [-2.87328603 -3.64871408 -1.6078202 ]
# 97  || [-3.03209034 -3.49428365 -0.57236421]
# 98  || [-3.03311583 -2.94769851  0.44103457]
# 99  || [-2.87630879 -4.24940096 -2.78260565]
# 100  || [-3.07463644 -4.06898092 -1.41854778]
# 101  || [-3.06937691 -3.5974469  -0.66477238]
# 102  || [-3.03773424 -3.06382349  0.23338577]
# 103  || [-2.76305675 -6.54519246 -7.76422787]
# 104  || [-3.01035997 -6.33130226 -4.2474935 ]
# 105  || [-3.46522086 -5.5002482  -2.903852  ]
# 106  || [-3.24347376 -4.69492041 -2.00591862]
# 107  || [-3.13457807 -4.05492947 -1.25418024]
# 108  || [-3.06867227 -3.53404534 -0.54633932]
# 109  || [-3.03688093 -2.94578922  0.45928534]
# 110  || [-2.88036362 -4.17173907 -2.61118612]
# 111  || [-3.06918805 -3.99085768 -1.31058466]
# 112  || [-3.06251585 -3.52739791 -0.55930565]
# 113  || [-3.03573192 -2.95337969  0.44043257]
# 114  || [-2.87759534 -4.24512012 -2.76734077]
# 115  || [-3.0745667  -4.063291   -1.41041974]
# 116  || [-3.06885227 -3.59229992 -0.65708982]
# 117  || [-3.03754771 -3.0563531   0.24715889]
# 118  || [-2.78491327 -6.15051269 -6.89749578]
# 119  || [-3.06929194 -5.9493428  -3.76332896]
# 120  || [-3.35157838 -5.16550227 -2.55966308]
# 121  || [-3.19408958 -4.43526351 -1.716257  ]
# 122  || [-3.10550698 -3.85081781 -0.99317706]
# 123  || [-3.05257694 -3.34591767 -0.25224378]
# 124  || [-3.04399354 -2.43235315  1.49410269]
# 125  || [-2.79579961 -2.93851638 -0.53501134]
# 126  || [-3.00575038 -2.6551431   0.97984541]
# 127  || [-2.85095682 -3.32863712 -1.06782425]
# 128  || [-3.01574961 -3.17502954 -0.02838386]
# 129  || [-3.10853763 -0.99052084  4.59691565]
# 130  || [-2.39003448 -1.10093049  1.51330525]
# 131  || [-1.98432892 -1.76125403 -2.06775976]
# 132  || [-2.42010626 -2.41037938  0.64105012]
# 133  || [-2.7644231  -3.8503181  -2.59557167]
# 134  || [-3.01968688 -3.83566504 -1.12205725]
# 135  || [-3.05195393 -3.39266032 -0.35023482]
# 136  || [-3.03708337 -2.64920264  1.04166036]
# 137  || [-2.85562492 -3.27437451 -0.95115958]
# 138  || [-3.0131813  -3.0984813   0.10953444]
# 139  || [-4.01580484 14.36912907 38.57434397]
# 140  || [-1.91069348 13.41795366 23.13612662]
# 141  || [-0.37833892 12.11350454 14.95881748]
# 142  || [ 1.19586832 11.04984374  9.46163124]
# 143  || [-1.95089724  5.35526294 12.08712205]
# 144  || [-0.77393436  5.04627079  7.14352585]
# 145  || [0.0354381  4.79029039 4.16162513]
# 146  || [0.6622945  5.4204846  1.28773629]
# 147  || [-0.40004309  5.66852131  0.67015226]
# 148  || [-0.80464905  1.80881581  1.1193918 ]
# 149  || [-0.72869083  3.68060396  0.86085805]
# 150  || [-1.00118334  2.82953852  1.04190686]
# 151  || [-0.9979625   3.00375215  0.99589103]
# 152  || [-1.00000019  2.99998756  1.00000033]
# 153  || [-1.  3.  1.]
# array([-1.,  3.,  1.])

# %%
# Newton meathod

def d_fn(x):
    x1, x2, x3 = x
    
    y1 = [3*x1**2+2*x2, 2*x1-x3, 2*x3-x2]
    y2 = [4*x1+2*x2**2, 4*x1*x2+3*(x2**2)*x3**2-2*x2*x3, 2*x2**3*x3-x2**2]
    y3 = [x2*x3+3*x1**2-x2**2, x1*x3-2*x1*x2, x1*x2-2*x3]

    D_f = np.array([y1,y2,y3])

    return D_f

d_fn(x01)
# Out:
# array([[  7.,  -1.,   4.],
#        [ 12., 104.,  44.],
#        [  5.,  -1.,  -4.]])

# %%
x_new = x01
x_old = x01 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_fn(x_old)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [1. 2. 3.]
# 2  || [ 0.5464  2.7784 -0.2616]
# 3  || [-2.45415693  7.13392934 -0.4031109 ]
# 4  || [-1.59789098  4.85550587 -0.37855094]
# 5  || [-1.42550577  3.00500187 -0.45121636]
# 6  || [-1.62369253  1.99376511 -0.67567152]
# 7  || [-1.69598454  1.97436714 -0.90336961]
# 8  || [-1.69054198  1.98302968 -0.88451335]
# 9  || [-1.69055076  1.98310724 -0.88455808]
# array([-1.69055076,  1.98310724, -0.88455808])

# %%
x_new = x02
x_old = x02 - 1
i = 1

while np.linalg.norm(f(x_new))>tol_approx or np.linalg.norm(x_new-x_old)>tol_consec:
    print(f"{i}  ||", x_new)
    x_old = x_new
    
    # find linear equation
    D_f = d_fn(x_old)
    F_old = f(x_old)
    inverse_matrix = np.linalg.inv(D_f)
    
    x_new = x_old - np.dot(inverse_matrix, F_old)
    
    i+=1
    
x_new
# Out:
# 1  || [2. 2. 2.]
# 2  || [-0.4516129  -5.35483871 16.46774194]
# 3  || [ 0.21571498 -5.66418297  6.75906942]
# 4  || [ 0.28602268 -6.52533239  1.79625249]
# 5  || [ -0.25842516 -12.48640211  -1.61432307]
# 6  || [ -0.08943887 -11.02414731  -1.10705913]
# 7  || [  0.72871695 -46.46470158   4.67295733]
# 8  || [ -1.10342368 -88.17585567  -3.96511265]
# 9  || [ -4.72168271  90.39754455 -14.0241217 ]
# 10  || [ 60.64551992 781.02052703 153.71581518]
# 11  || [ 42.27036841 536.00866542 149.19075827]
# 12  || [ 30.58967197 370.11954882 143.85513179]
# 13  || [ 22.57214085 260.76158673 135.6845358 ]
# 14  || [ 16.41142142 189.53209514 123.43811908]
# 15  || [ 11.38871927 141.72768054 108.42087148]
# 16  || [  7.1707915 107.9425363  92.9798313]
# 17  || [ 3.26696773 82.65698532 79.16250206]
# 18  || [-3.57937316 60.38566804 71.57890941]
# 19  || [-0.30297905 51.05268886 52.3872161 ]
# 20  || [ 7.10058345 46.62219945 33.01486143]
# 21  || [ 4.17426438 35.05855147 28.79399271]
# 22  || [ 1.69039444 26.05067297 25.50016356]
# 23  || [-9.09549921 11.00212362 34.86666842]
# 24  || [-5.58788429 10.44314093 20.12391331]
# 25  || [-3.25868715  9.42580065 13.03440124]
# 26  || [-1.58358467  8.26022708  8.96472139]
# 27  || [-0.2579241   7.32630336  6.02892477]
# 28  || [1.34263684 7.88573101 2.33197732]
# 29  || [0.38981462 6.14796883 1.97510188]
# 30  || [-0.21310621  5.77647455  1.23176329]
# 31  || [-0.65185811  1.77295091  1.96808574]
# 32  || [-0.83567583  2.55767021  0.42313849]
# 33  || [0.53002218 6.2034857  3.60741047]
# 34  || [-0.48001184  3.64393483  4.10459496]
# 35  || [-0.14527717  3.72163095  2.01066141]
# 36  || [-0.73482511  3.64441127  1.25111857]
# 37  || [-0.94294292  3.09679016  1.15376127]
# 38  || [-0.99035772  3.01969206  1.01922456]
# 39  || [-0.99976961  3.00048207  1.00053964]
# 40  || [-0.99999983  3.00000036  1.00000039]
# array([-1.,  3.,  1.])

# %%
# def d_f(x,h):
#     a = []
#     for j in range(3):
#         x_addh = np.copy(x)
#         x_minh = np.copy(x)
#         x_addh[j] = x[j]+h
# #         print(x_addh[j])
#         x_minh[j] = x[j]-h
# #         print(x_minh[j])
# #         print(x_addh, x_minh, (f(x_addh)-f(x_minh))/2/h)
#         a.append((f(x_addh)-f(x_minh))/2/h)
    
#     res = np.array(a)
    
#     return res

    

    
# F_old = np.array(f(x01))
    
# inverse_matrix = np.linalg.inv(res_array)

# x_new = f(x01) - np.dot(inverse_matrix, F_old)

# %% [markdown]
# # Question 7

# %%
# using newtons method to bootstrap 0 rates
# at .5 to 2 year
r_5 = np.log(100/97.5)/.5

def f2(x):
    y = -100-5/32+2.4375*np.exp(-.5*r_5)+2.4375*np.exp(-(r_5+.5*x)/1.5)+2.4375*np.exp(-1.5*(.5*r_5+x)/1.5)+102.4375*np.exp(-2*x)
    return y

def d_f2(x):
    d_y = 2.4375*-.5/1.5*np.exp(-(r_5+.5*x)/1.5)+2.4375*(-1.5/1.5)*np.exp(-1.5*(.5*r_5+x)/1.5)+102.4375*-2*np.exp(-2*x)
    return d_y

x0 = .047
tol_approx = 1e-9
tol_consec = 1e-6

x_new = x0
x_old = x0-1

while abs(f2(x_new))>tol_approx or abs(x_new-x_old)>tol_consec:
    x_old = x_new
    x_new = x_old - f2(x_old)/d_f2(x_old)

    print(x_new, x_old)

r2 = x_new
r1_5 = (.5*r_5+r2)/1.5
r1 = (r_5+.5*r2)/1.5
# Out:
# 0.047289178936440954 0.047
# 0.04728926180791532 0.047289178936440954

# %%
# using newtons method to bootstrap 0 rates
# at 2 to 3 year

def f3(x):
    y = -100-5/32+2.4375*np.exp(-.5*r_5)+2.4375*np.exp(-1*r1)+2.4375*np.exp(-1.5*r1_5)+2.4375*np.exp(-2*r2)+2.4375*np.exp(-2.5*.5*(x+r2))+102.4375*np.exp(-3*x)
    
    return y

def d_f3(x):
    d_y = 2.4375*-2.5*.5*np.exp(-2.5*.5*(r2+x))+102.4375*-3*np.exp(-3*x)
    return d_y

x0 = .047
tol_approx = 1e-9
tol_consec = 1e-6

x_new = x0
x_old = x0-1

while abs(f3(x_new))>tol_approx or abs(x_new-x_old)>tol_consec:
    x_old = x_new
    x_new = x_old - f3(x_old)/d_f3(x_old)

    print(x_new, x_old)
    
r3 = x_new
r2_5 = .5*r3 + .5*r2
# Out:
# 0.047581370852375224 0.047
# 0.047581875451800544 0.047581370852375224

# %%
# at 3 to 5 year
def f5(x):
    r3_5 = (.5*x+1.5*r3)/2
    r4 = (x+r3)/2
    r4_5 = (1.5*x+.5*r3)/2
    r5 = x
    
    y = -99.6875+2.3125*np.exp(-.5*r_5)+2.3125*np.exp(-1*r1)+2.3125*np.exp(-1.5*r1_5)+2.3125*np.exp(-2*r2)+2.3125*np.exp(-2.5*r2_5)+2.3125*np.exp(-3*r3)+2.3125*np.exp(-3.5*r3_5)+2.3125*np.exp(-4*r4)+2.3125*np.exp(-4.5*r4_5)+102.3125*np.exp(-5*r5)
    
    return y

def d_f5(x):
    d_y = 2.3125*-.875*np.exp(-3.5*(.5*x+1.5*r3)/2)+2.3125*-2*np.exp(-2*(x+r3)/2)+2.3125*-3.375*np.exp(-4.5*(1.5*x+0.5*r3)/2)+102.3125*-5*np.exp(-5*x)
    return d_y

# %%
x0 = r3
tol_approx = 1e-9
tol_consec = 1e-6

x_new = x0
x_old = x0-1

while abs(f5(x_new))>tol_approx or abs(x_new-x_old)>tol_consec:
    x_old = x_new
    x_new = x_old - f5(x_old)/d_f5(x_old)

    print(x_new, x_old)
    
r5 = x_new
r4_5 = (1.5*x_new + .5*r3)/2
r4 = (x_new + r3)/2
r3_5 = (.5*x_new + 1.5*r3)/2
# Out:
# 0.04630049937344657 0.047581875451800544
# 0.04630335677958187 0.04630049937344657
# 0.046303359378376534 0.04630335677958187

# %%
r5, r4_5, r4, r3_5
# Out:
# (0.046303359378376534,
#  0.04662298839673253,
#  0.04694261741508854,
#  0.047262246433444545)

# %%
# at 5 to 10 year
def f10(x):
    r5_5 = .1*x + .9*r5
    r6   = .2*x + .8*r5
    r6_5 = .3*x + .7*r5
    r7   = .4*x + .6*r5
    r7_5 = .5*x + .5*r5
    r8   = .6*x + .4*r5
    r8_5 = .7*x + .3*r5
    r9   = .8*x + .2*r5
    r9_5 = .9*x + .1*r5
    r10  =    x
    
    
    y = -101.125+2.4375*np.exp(-.5*r_5)+2.4375*np.exp(-1*r1)+2.4375*np.exp(-1.5*r1_5)+2.4375*np.exp(-2*r2)+2.4375*np.exp(-2.5*r2_5)+2.4375*np.exp(-3*r3)+2.4375*np.exp(-3.5*r3_5)+2.4375*np.exp(-4*r4)+2.4375*np.exp(-4.5*r4_5)+2.4375*np.exp(-5*r5)+2.4375*np.exp(-5.5*r5_5)+2.4375*np.exp(-6*r6)+2.4375*np.exp(-6.5*r6_5)+2.4375*np.exp(-7*r7)+2.4375*np.exp(-7.5*r7_5)+2.4375*np.exp(-8*r8)+2.4375*np.exp(-8.5*r8_5)+2.4375*np.exp(-9*r9)+2.4375*np.exp(-9.5*r9_5)+102.4375*np.exp(-10*r10)
    
    return y

def d_f10(x):
    r5_5 = .1*x + .9*r5
    r6   = .2*x + .8*r5
    r6_5 = .3*x + .7*r5
    r7   = .4*x + .6*r5
    r7_5 = .5*x + .5*r5
    r8   = .6*x + .4*r5
    r8_5 = .7*x + .3*r5
    r9   = .8*x + .2*r5
    r9_5 = .9*x + .1*r5
    r10  =    x
    
    d_y = 2.4375*-5.5*.1*np.exp(-5.5*r5_5)+2.4375*-6*.2*np.exp(-6*r6)+2.4375*-6.5*.3*np.exp(-6.5*r6_5)+2.4375*-7*.4*np.exp(-7*r7)+2.4375*-7.5*.5*np.exp(-7.5*r7_5)+2.4375*-8*.6*np.exp(-8*r8)+2.4375*-8.5*.7*np.exp(-8.5*r8_5)+2.4375*-9*.8*np.exp(-9*r9)+2.4375*-9.5*.9*np.exp(-9.5*r9_5)+102.4375*-10*np.exp(-10*r10)
    
    return d_y

# %%
x0 = r5
tol_approx = 1e-9
tol_consec = 1e-6

x_new = x0
x_old = x0-1

while abs(f10(x_new))>tol_approx or abs(x_new-x_old)>tol_consec:
    x_old = x_new
    x_new = x_old - f10(x_old)/d_f10(x_old)

    print(x_new, x_old)
    
r5_5 = .1*x_new + .9*r5
r6   = .2*x_new + .8*r5
r6_5 = .3*x_new + .7*r5
r7   = .4*x_new + .6*r5
r7_5 = .5*x_new + .5*r5
r8   = .6*x_new + .4*r5
r8_5 = .7*x_new + .3*r5
r9   = .8*x_new + .2*r5
r9_5 = .9*x_new + .1*r5
r10  =    x_new
# Out:
# 0.04677101007728406 0.046303359378376534
# 0.04677206531614356 0.04677101007728406
# 0.046772065321500064 0.04677206531614356

# %%
r_5, r2, r3, r5, r10
# Out:
# (0.05063561596857957,
#  0.04728926180791532,
#  0.047581875451800544,
#  0.046303359378376534,
#  0.046772065321500064)
