# %%
import pandas as pd
import numpy as np
import polars as pl

# %%
df_master = pl.read_csv("../data/master_file.csv")
df_master.head()
# Out:
# shape: (5, 40)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ date      ┆ symbol_15 ┆ sec_desc  ┆ cusip     ┆ … ┆ effective ┆ tron_ltse ┆ tron_memx ┆ tron_mia │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ _date     ┆ ---       ┆ ---       ┆ x        │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2023-01-0 ┆ A         ┆ Agilent   ┆ 00846U101 ┆ … ┆ 1999-11-1 ┆ 0         ┆ 1         ┆ 1        │
# │ 3         ┆           ┆ Technolog ┆           ┆   ┆ 8         ┆           ┆           ┆          │
# │           ┆           ┆ ies Inc.  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-01-0 ┆ AA        ┆ Alcoa Cor ┆ 013872106 ┆ … ┆ 2016-10-1 ┆ 0         ┆ 1         ┆ 1        │
# │ 3         ┆           ┆ poration  ┆           ┆   ┆ 8         ┆           ┆           ┆          │
# │ 2023-01-0 ┆ AAA       ┆ AXS First ┆ 46144X610 ┆ … ┆ 2022-10-1 ┆ 0         ┆ 0         ┆ 0        │
# │ 3         ┆           ┆ Priority  ┆           ┆   ┆ 7         ┆           ┆           ┆          │
# │           ┆           ┆ CLO Bond  ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ET…       ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-01-0 ┆ AAAU      ┆ Goldman   ┆ 38150K103 ┆ … ┆ null      ┆ 0         ┆ 1         ┆ 1        │
# │ 3         ┆           ┆ Sachs     ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Physical  ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ Gold ET…  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2023-01-0 ┆ AAC       ┆ Ares Acqu ┆ G33032106 ┆ … ┆ 2021-03-2 ┆ 0         ┆ 1         ┆ 1        │
# │ 3         ┆           ┆ isition   ┆           ┆   ┆ 5         ┆           ┆           ┆          │
# │           ┆           ┆ Corporati ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ on        ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_master['symbol_15'].unique().shape
# Out:
# (13101,)

# %%
df_master.describe()
# Out:
# shape: (9, 41)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ date      ┆ symbol_15 ┆ sec_desc  ┆ … ┆ effective ┆ tron_ltse ┆ tron_memx ┆ tron_mia │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ _date     ┆ ---       ┆ ---       ┆ x        │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ f64       ┆ f64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ str       ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 2864764   ┆ 2864764   ┆ 2864764   ┆ … ┆ 1392403   ┆ 2.864764e ┆ 2.864764e ┆ 2.864764 │
# │           ┆           ┆           ┆           ┆   ┆           ┆ 6         ┆ 6         ┆ e6       │
# │ null_coun ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 1472361   ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.013266  ┆ 0.700164  ┆ 0.547762 │
# │ std       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.114412  ┆ 0.458186  ┆ 0.497714 │
# │ min       ┆ 2023-01-0 ┆ A         ┆ X-Square  ┆ … ┆ 1892-06-2 ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │           ┆ 3         ┆           ┆ Municipal ┆   ┆ 3         ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Income    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Tax…      ┆   ┆           ┆           ┆           ┆          │
# │ 25%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ 50%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.0       ┆ 1.0       ┆ 1.0      │
# │ 75%       ┆ null      ┆ null      ┆ null      ┆ … ┆ null      ┆ 0.0       ┆ 1.0       ┆ 1.0      │
# │ max       ┆ 2023-12-2 ┆ ZZZ       ┆ vTv Thera ┆ … ┆ 2033-03-0 ┆ 1.0       ┆ 1.0       ┆ 1.0      │
# │           ┆ 9         ┆           ┆ peutics   ┆   ┆ 1         ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Inc.      ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ Class A … ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
symbols_10may2023 = (
    df_master
    .filter(pl.col("date") == "2023-05-10")
    .select("symbol_15")
    .unique()
)
print(symbols_10may2023)
# Out:
# shape: (11_508, 1)
# ┌───────────┐
# │ symbol_15 │
# │ ---       │
# │ str       │
# ╞═══════════╡
# │ BANF      │
# │ CEFA      │
# │ TECH      │
# │ WBX       │
# │ EAI       │
# │ …         │
# │ ANEB      │
# │ UAL       │
# │ SBB       │
# │ RACY W    │
# │ MTB PRH   │
# └───────────┘

# %%
df = pl.read_csv(
    "../data/aapl_1993.csv",
    schema_overrides={"NATBBO_IND": pl.Utf8}
)

# %%
df
# Out:
# shape: (3_163, 10)
# ┌────────┬────────────┬──────────┬─────────┬───┬────────┬──────┬─────┬──────┐
# │ SYMBOL ┆ DATE       ┆ TIME     ┆ BID     ┆ … ┆ OFRSIZ ┆ MODE ┆ EX  ┆ MMID │
# │ ---    ┆ ---        ┆ ---      ┆ ---     ┆   ┆ ---    ┆ ---  ┆ --- ┆ ---  │
# │ str    ┆ str        ┆ str      ┆ f64     ┆   ┆ i64    ┆ i64  ┆ str ┆ str  │
# ╞════════╪════════════╪══════════╪═════════╪═══╪════════╪══════╪═════╪══════╡
# │ AAPL   ┆ 1999-05-05 ┆ 8:15:34  ┆ 46.5    ┆ … ┆ 10     ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 8:54:01  ┆ 46.5625 ┆ … ┆ 10     ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 8:54:03  ┆ 46.5625 ┆ … ┆ 10     ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 9:07:12  ┆ 46.5625 ┆ … ┆ 1      ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 9:09:41  ┆ 46.5625 ┆ … ┆ 10     ┆ 12   ┆ T   ┆ null │
# │ …      ┆ …          ┆ …        ┆ …       ┆ … ┆ …      ┆ …    ┆ …   ┆ …    │
# │ AAPL   ┆ 1999-05-05 ┆ 15:58:59 ┆ 46.875  ┆ … ┆ 0      ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 15:59:05 ┆ 46.9375 ┆ … ┆ 0      ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 15:59:05 ┆ 0.0     ┆ … ┆ 2      ┆ 12   ┆ M   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 15:59:50 ┆ 46.875  ┆ … ┆ 0      ┆ 12   ┆ T   ┆ null │
# │ AAPL   ┆ 1999-05-05 ┆ 15:59:50 ┆ 0.0     ┆ … ┆ 2      ┆ 12   ┆ M   ┆ null │
# └────────┴────────────┴──────────┴─────────┴───┴────────┴──────┴─────┴──────┘

# %%
non_numeric_natbbo = df.filter(~pl.col("NATBBO_IND").cast(pl.Float64, strict=False).is_not_null())
non_numeric_natbbo.select("SYM_ROOT").unique()
# Out:
# shape: (3, 1)
# ┌──────────┐
# │ SYM_ROOT │
# │ ---      │
# │ str      │
# ╞══════════╡
# │ XOM      │
# │ XBI      │
# │ DPZ      │
# └──────────┘

# %%
# df = pl.read_csv("../data/stock_sample7.csv")
# Ensure TIME_M is parsed as a datetime column with strict=False to handle invalid formats
df = df.with_columns(
    pl.col("TIME_M").str.to_time(format="%H:%M:%S%.f").alias("TIME_M")
)

# Filter rows between 9:30:00 and 16:00:00
df = df.filter(
    pl.col("TIME_M").is_between(pl.time(9, 30), pl.time(16, 0))
)

df.shape
# Out:
# (6532952, 14)

# %%
df['SYM_ROOT'].value_counts()
# Out:
# shape: (3, 2)
# ┌──────────┬─────────┐
# │ SYM_ROOT ┆ count   │
# │ ---      ┆ ---     │
# │ str      ┆ u32     │
# ╞══════════╪═════════╡
# │ XOM      ┆ 3738445 │
# │ XBI      ┆ 2655843 │
# │ DPZ      ┆ 138664  │
# └──────────┴─────────┘

# %%
df['QU_CANCEL'].value_counts()
# Out:
# shape: (1, 2)
# ┌───────────┬─────────┐
# │ QU_CANCEL ┆ count   │
# │ ---       ┆ ---     │
# │ str       ┆ u32     │
# ╞═══════════╪═════════╡
# │ null      ┆ 6532952 │
# └───────────┴─────────┘

# %% [markdown]
# # TAQ Quote - Data Dictionary
# Exchange that issued the quote (EX)
#
# Bid price (BID)
#
# Bid size in units of trade (BIDSIZ)
#
# Ask price (ASK)
#
# Ask size in units of trade (ASKSIZ)
#
# Condition of quote issued (QU_COND)
#
# Bid exchange (BIDEX)
#
# Ask exchange (ASKEX)
#
# Quote Sequence Number (QU_SEQNUM)
#
# National BBO Indicator (NATBBO_IND)
#
# NASD BBO Indicator (NASDBBO_IND)
#
# Quote Cancel/Correction (QU_CANCEL)
#
# Source of Quote (QU_SOURCE)
#
# ## Quote Condition
# ‘R’ = Regular, two-sided open quote
#
# ‘L’ = Closed Market Maker (NASD)
#
# ‘Y’ = Regular - One Sided Quote (NASDAQ)
#
# # single exchange
# 1. find the most liquid exchange ==> narrow apread
#     - filter all two-sided quotes and get the narrowest average for each exchange
# 2. filter for liquid exchange

# %%
df['QU_COND'].value_counts()
# Out:
# shape: (2, 2)
# ┌─────────┬─────────┐
# │ QU_COND ┆ count   │
# │ ---     ┆ ---     │
# │ str     ┆ u32     │
# ╞═════════╪═════════╡
# │ O       ┆ 2       │
# │ R       ┆ 6532950 │
# └─────────┴─────────┘

# %%
# Filter for rows where QU_COND is 'R'
filtered_df = df.filter(pl.col("QU_COND") == "N")

# Create a new column 'spread' calculated as ASK - BID
filtered_df = filtered_df.with_columns((pl.col("ASK") - pl.col("BID")).alias("spread"))

# Aggregate by EX column and calculate the average spread
average_spread = (
	filtered_df
	.group_by("EX")
	.agg(pl.col("spread").mean().alias("average_spread"),
        pl.col("spread").count().alias("count"))
    .sort("count")
)

average_spread
# Out:
# shape: (0, 3)
# ┌─────┬────────────────┬───────┐
# │ EX  ┆ average_spread ┆ count │
# │ --- ┆ ---            ┆ ---   │
# │ str ┆ f64            ┆ u32   │
# ╞═════╪════════════════╪═══════╡
# └─────┴────────────────┴───────┘

# %% [markdown]
# *** EX Q (NASDAQ) has the tightest spread, also has the highest refresh. We assume we can connect directly with NASDAQ ***
#
# for 10 May aapl stock:
# - K (Direct X) performance is very bad
# - Z (BATS) performance is still reasonable
# - N (NYSE)

# %%
filtered_df.filter(pl.col("EX").is_in(["N"]))['spread'].describe()
# filtered_df.filter(pl.col("EX").is_in(["K"]))['spread'].describe()
# filtered_df.filter(pl.col("EX").is_in(["Z"]))['spread'].describe()
# Out:
# shape: (2, 2)
# ┌────────────┬───────┐
# │ statistic  ┆ value │
# │ ---        ┆ ---   │
# │ str        ┆ f64   │
# ╞════════════╪═══════╡
# │ count      ┆ 0.0   │
# │ null_count ┆ 0.0   │
# └────────────┴───────┘

# %%
df.head()
# Out:
# shape: (5, 14)
# ┌────────────┬──────────────────┬─────┬────────┬───┬───────────┬───────────┬──────────┬────────────┐
# │ DATE       ┆ TIME_M           ┆ EX  ┆ BID    ┆ … ┆ QU_CANCEL ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX │
# │ ---        ┆ ---              ┆ --- ┆ ---    ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---        │
# │ str        ┆ time             ┆ str ┆ f64    ┆   ┆ str       ┆ str       ┆ str      ┆ str        │
# ╞════════════╪══════════════════╪═════╪════════╪═══╪═══════════╪═══════════╪══════════╪════════════╡
# │ 2023-06-21 ┆ 09:30:00.0062343 ┆ J   ┆ 317.99 ┆ … ┆ null      ┆ C         ┆ DPZ      ┆ null       │
# │            ┆ 68               ┆     ┆        ┆   ┆           ┆           ┆          ┆            │
# │ 2023-06-21 ┆ 09:30:00.0129904 ┆ T   ┆ 317.99 ┆ … ┆ null      ┆ C         ┆ DPZ      ┆ null       │
# │            ┆ 64               ┆     ┆        ┆   ┆           ┆           ┆          ┆            │
# │ 2023-06-21 ┆ 09:30:00.0328076 ┆ T   ┆ 317.99 ┆ … ┆ null      ┆ C         ┆ DPZ      ┆ null       │
# │            ┆ 80               ┆     ┆        ┆   ┆           ┆           ┆          ┆            │
# │ 2023-06-21 ┆ 09:30:00.0333992 ┆ B   ┆ 255.99 ┆ … ┆ null      ┆ C         ┆ DPZ      ┆ null       │
# │            ┆ 96               ┆     ┆        ┆   ┆           ┆           ┆          ┆            │
# │ 2023-06-21 ┆ 09:30:00.0825510 ┆ V   ┆ 256.97 ┆ … ┆ null      ┆ C         ┆ DPZ      ┆ null       │
# │            ┆ 40               ┆     ┆        ┆   ┆           ┆           ┆          ┆            │
# └────────────┴──────────────────┴─────┴────────┴───┴───────────┴───────────┴──────────┴────────────┘

# %%
df.with_columns(
    pl.when(
                (pl.col("TIME_M") < pl.time(*(10, 35, 865))) |
                (pl.col("TIME_M") < pl.time(*(12, 35, 865))) 
            )
    .then(0)
    )
# Out:
# shape: (6_532_952, 15)
# ┌────────────┬────────────────────┬─────┬────────┬───┬───────────┬──────────┬────────────┬─────────┐
# │ DATE       ┆ TIME_M             ┆ EX  ┆ BID    ┆ … ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX ┆ literal │
# │ ---        ┆ ---                ┆ --- ┆ ---    ┆   ┆ ---       ┆ ---      ┆ ---        ┆ ---     │
# │ str        ┆ time               ┆ str ┆ f64    ┆   ┆ str       ┆ str      ┆ str        ┆ i32     │
# ╞════════════╪════════════════════╪═════╪════════╪═══╪═══════════╪══════════╪════════════╪═════════╡
# │ 2023-06-21 ┆ 09:30:00.006234368 ┆ J   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 09:30:00.012990464 ┆ T   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 09:30:00.032807680 ┆ T   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 09:30:00.033399296 ┆ B   ┆ 255.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 09:30:00.082551040 ┆ V   ┆ 256.97 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ null    │
# │ …          ┆ …                  ┆ …   ┆ …      ┆ … ┆ …         ┆ …        ┆ …          ┆ …       │
# │ 2023-06-21 ┆ 15:59:59.998444800 ┆ M   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 15:59:59.998594816 ┆ Z   ┆ 103.86 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 15:59:59.998669824 ┆ U   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 15:59:59.998690048 ┆ U   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ null    │
# │ 2023-06-21 ┆ 15:59:59.999837696 ┆ N   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ null    │
# └────────────┴────────────────────┴─────┴────────┴───┴───────────┴──────────┴────────────┴─────────┘

# %%
df.with_columns(
    pl.when(
        (pl.col("TIME_M") < pl.time(10, 35)) |
        (pl.col("TIME_M") > pl.time(12, 35))
    )
    .then(pl.lit(0))
    .alias("FILTER_FLAG")
)
# Out:
# shape: (6_532_952, 15)
# ┌────────────┬────────────────┬─────┬────────┬───┬───────────┬──────────┬────────────┬─────────────┐
# │ DATE       ┆ TIME_M         ┆ EX  ┆ BID    ┆ … ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX ┆ FILTER_FLAG │
# │ ---        ┆ ---            ┆ --- ┆ ---    ┆   ┆ ---       ┆ ---      ┆ ---        ┆ ---         │
# │ str        ┆ time           ┆ str ┆ f64    ┆   ┆ str       ┆ str      ┆ str        ┆ i32         │
# ╞════════════╪════════════════╪═════╪════════╪═══╪═══════════╪══════════╪════════════╪═════════════╡
# │ 2023-06-21 ┆ 09:30:00.00623 ┆ J   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ 0           │
# │            ┆ 4368           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 09:30:00.01299 ┆ T   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ 0           │
# │            ┆ 0464           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 09:30:00.03280 ┆ T   ┆ 317.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ 0           │
# │            ┆ 7680           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 09:30:00.03339 ┆ B   ┆ 255.99 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ 0           │
# │            ┆ 9296           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 09:30:00.08255 ┆ V   ┆ 256.97 ┆ … ┆ C         ┆ DPZ      ┆ null       ┆ 0           │
# │            ┆ 1040           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ …          ┆ …              ┆ …   ┆ …      ┆ … ┆ …         ┆ …        ┆ …          ┆ …           │
# │ 2023-06-21 ┆ 15:59:59.99844 ┆ M   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ 0           │
# │            ┆ 4800           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 15:59:59.99859 ┆ Z   ┆ 103.86 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ 0           │
# │            ┆ 4816           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 15:59:59.99866 ┆ U   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ 0           │
# │            ┆ 9824           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 15:59:59.99869 ┆ U   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ 0           │
# │            ┆ 0048           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# │ 2023-06-21 ┆ 15:59:59.99983 ┆ N   ┆ 103.87 ┆ … ┆ C         ┆ XOM      ┆ null       ┆ 0           │
# │            ┆ 7696           ┆     ┆        ┆   ┆           ┆          ┆            ┆             │
# └────────────┴────────────────┴─────┴────────┴───┴───────────┴──────────┴────────────┴─────────────┘

# %%
# df.head(100).to_pandas().plot.line(x="QU_SEQNUM", y="OBI")

# %%
del filtered_df
del average_spread

# %% [markdown]
# # Data prep
# 1. filter trading hours
# 2. Nasdaq quotes
# 3. take twosided quotes only

# %%
# filter trading hours
# df = df.with_columns(
#     pl.col("TIME_M").str.to_time(format="%H:%M:%S%.f").alias("TIME_M")
# )
df = df.filter(pl.col("SYM_ROOT") == "AAPL")
df = df.filter(
    pl.col("TIME_M").is_between(pl.time(10, 30), pl.time(12, 0))
)
# Filter for Nasdaq exchange
df = df.filter(pl.col("EX") == "N")
# Filter for rows where QU_COND is 'R'
df = df.filter(pl.col("QU_COND") == "R")
df.shape
# Out:
# (0, 14)

# %%
df.head()
# Out:
# shape: (0, 14)
# ┌──────┬────────┬─────┬─────┬───┬───────────┬───────────┬──────────┬────────────┐
# │ DATE ┆ TIME_M ┆ EX  ┆ BID ┆ … ┆ QU_CANCEL ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX │
# │ ---  ┆ ---    ┆ --- ┆ --- ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---        │
# │ str  ┆ time   ┆ str ┆ f64 ┆   ┆ str       ┆ str       ┆ str      ┆ str        │
# ╞══════╪════════╪═════╪═════╪═══╪═══════════╪═══════════╪══════════╪════════════╡
# └──────┴────────┴─────┴─────┴───┴───────────┴───────────┴──────────┴────────────┘

# %%
df.describe()
# Out:
# shape: (9, 15)
# ┌────────────┬──────┬────────┬──────┬───┬───────────┬───────────┬──────────┬────────────┐
# │ statistic  ┆ DATE ┆ TIME_M ┆ EX   ┆ … ┆ QU_CANCEL ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX │
# │ ---        ┆ ---  ┆ ---    ┆ ---  ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---        │
# │ str        ┆ str  ┆ str    ┆ str  ┆   ┆ str       ┆ str       ┆ str      ┆ str        │
# ╞════════════╪══════╪════════╪══════╪═══╪═══════════╪═══════════╪══════════╪════════════╡
# │ count      ┆ 0    ┆ 0      ┆ 0    ┆ … ┆ 0         ┆ 0         ┆ 0        ┆ 0          │
# │ null_count ┆ 0    ┆ 0      ┆ 0    ┆ … ┆ 0         ┆ 0         ┆ 0        ┆ 0          │
# │ mean       ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ std        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ min        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ 25%        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ 50%        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ 75%        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# │ max        ┆ null ┆ null   ┆ null ┆ … ┆ null      ┆ null      ┆ null     ┆ null       │
# └────────────┴──────┴────────┴──────┴───┴───────────┴───────────┴──────────┴────────────┘

# %%
df['NATBBO_IND'].value_counts()
# Out:
# shape: (0, 2)
# ┌────────────┬───────┐
# │ NATBBO_IND ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# └────────────┴───────┘

# %% [markdown]
# ### National Best Bid-Offer (NBBO) - Legend
# ‘0’ = No National BBO change - Current quote does not affect the BBO. No National appendage is required.
#
# ‘1’ = No National BBO Can be Calculated- The National BBO cannot be calculated therefore vendors should show National BBO fields as blank. No Appendage is required.
#
# ‘2’ = Short Form National BBO Appendage Attached – A new National BBO was generated as a result of the UTP participant’s quote update and the new information is contained in the short form appendage (NBBO FILE)
#
# ‘3’ = Long Format of National BBO Appendage - A new National BBO is generated and the new BBO information is contained in the Long National BBO appendage (NBBO FILE)
#
# ‘4’ = Quote Contains all NASD BBO Information - Current quote is itself the new NASD BBO. No NASD appendage is required.
#
# ---
# In the case above, I will track all bid offer and size regardless of NATBBO indicator

# %%
df['QU_COND'].value_counts()
# Out:
# shape: (0, 2)
# ┌─────────┬───────┐
# │ QU_COND ┆ count │
# │ ---     ┆ ---   │
# │ str     ┆ u32   │
# ╞═════════╪═══════╡
# └─────────┴───────┘

# %%
df.glimpse
# Out:
# <bound method DataFrame.glimpse of shape: (0, 14)
# ┌──────┬────────┬─────┬─────┬───┬───────────┬───────────┬──────────┬────────────┐
# │ DATE ┆ TIME_M ┆ EX  ┆ BID ┆ … ┆ QU_CANCEL ┆ QU_SOURCE ┆ SYM_ROOT ┆ SYM_SUFFIX │
# │ ---  ┆ ---    ┆ --- ┆ --- ┆   ┆ ---       ┆ ---       ┆ ---      ┆ ---        │
# │ str  ┆ time   ┆ str ┆ f64 ┆   ┆ str       ┆ str       ┆ str      ┆ str        │
# ╞══════╪════════╪═════╪═════╪═══╪═══════════╪═══════════╪══════════╪════════════╡
# └──────┴────────┴─────┴─────┴───┴───────────┴───────────┴──────────┴────────────┘>

# %%
df.columns
# Out:
# ['DATE',
#  'TIME_M',
#  'EX',
#  'BID',
#  'BIDSIZ',
#  'ASK',
#  'ASKSIZ',
#  'QU_COND',
#  'QU_SEQNUM',
#  'NATBBO_IND',
#  'QU_CANCEL',
#  'QU_SOURCE',
#  'SYM_ROOT',
#  'SYM_SUFFIX']

# %% [markdown]
# # Try OBI strategy

# %%
class OBIVWAPStrategy:
    def __init__(self, vwap_window: int, obi_threshold: float, initial_cash: float = 100_000):
        self.vwap_window = vwap_window
        self.obi_threshold = obi_threshold
        self.cash = initial_cash
        self.position = 0
        self.account_balance = []

    def calculate_vwap(self, df: pl.DataFrame) -> pl.DataFrame:
        # Calculate MID_PRICE
        df = df.with_columns(
            ((pl.col("BID") + pl.col("ASK")) / 2).alias("MID_PRICE")
        )
        # Calculate Volume
        df = df.with_columns(
            (pl.col("BIDSIZ") + pl.col("ASKSIZ")).alias("Volume")
        )
        # Calculate VWAP using rolling window
        df = df.with_columns(
            (
                (pl.col("MID_PRICE") * pl.col("Volume"))
                .rolling_sum(window_size=self.vwap_window)
                / pl.col("Volume").rolling_sum(window_size=self.vwap_window)
            ).alias("VWAP")
        )
        return df

    def calculate_obi(self, df: pl.DataFrame) -> pl.DataFrame:
        # Calculate Order Book Imbalance (OBI)
        df = df.with_columns(
            (
                (pl.col("BIDSIZ") - pl.col("ASKSIZ"))
                / (pl.col("BIDSIZ") + pl.col("ASKSIZ"))
            ).alias("OBI")
        )
        return df

    def generate_signals(self, df: pl.DataFrame) -> pl.DataFrame:
        # Calculate VWAP and OBI
        df = self.calculate_vwap(df)
        df = self.calculate_obi(df)

        # Generate signals based on OBI threshold
        df = df.with_columns(
            pl.when(pl.col("OBI") > self.obi_threshold)
            .then(1)  # Buy signal
            .when(pl.col("OBI") < -self.obi_threshold)
            .then(-1)  # Sell signal
            .otherwise(0)  # No signal
            .alias("Signal")
        )
        return df

    def backtest(self, df: pl.DataFrame) -> pl.DataFrame:
        # Initialize account balance tracking
        account_balance = []

        # Iterate over rows to simulate trading
        for row in df.iter_rows(named=True):
            if row["Signal"] == 1 and self.cash >= row["ASK"] * 100 and self.position <= 1:
                # Buy 100 shares
                self.position = 100
                self.cash -= row["ASK"] * 100
            elif row["Signal"] == -1 and self.position > -1:
                # Sell 100 shares
                self.position = -100
                self.cash += row["BID"] * 100
            elif row["Signal"] == 0 and self.position != 0:
                # Close position
                if self.position > 0:
                    self.cash += row["BID"] * self.position
                else:
                    self.cash -= row["ASK"] * abs(self.position)
                self.position = 0

            # Record account balance
            account_balance.append(self.cash + self.position * (row["ASK"] if self.position > 0 else row["BID"]))

        # Add account balance to the DataFrame
        df = df.with_columns(pl.Series("Account_Balance", account_balance))
        return df

# %%
strategy = OBIVWAPStrategy(vwap_window=50, obi_threshold=0.2)
signal_data = strategy.generate_signals(df)
backtest_data = strategy.backtest(signal_data)

print(backtest_data.head())
# Out:
# shape: (0, 20)
# ┌──────┬────────┬─────┬─────┬───┬──────┬─────┬────────┬─────────────────┐
# │ DATE ┆ TIME_M ┆ EX  ┆ BID ┆ … ┆ VWAP ┆ OBI ┆ Signal ┆ Account_Balance │
# │ ---  ┆ ---    ┆ --- ┆ --- ┆   ┆ ---  ┆ --- ┆ ---    ┆ ---             │
# │ str  ┆ time   ┆ str ┆ f64 ┆   ┆ f64  ┆ f64 ┆ i32    ┆ null            │
# ╞══════╪════════╪═════╪═════╪═══╪══════╪═════╪════════╪═════════════════╡
# └──────┴────────┴─────┴─────┴───┴──────┴─────┴────────┴─────────────────┘

# %%
backtest_data["Account_Balance"].describe()
# Out:
# shape: (2, 2)
# ┌────────────┬───────┐
# │ statistic  ┆ value │
# │ ---        ┆ ---   │
# │ str        ┆ f64   │
# ╞════════════╪═══════╡
# │ count      ┆ 0.0   │
# │ null_count ┆ 0.0   │
# └────────────┴───────┘

# %%
backtest_data.columns
# Out:
# ['DATE',
#  'TIME_M',
#  'EX',
#  'BID',
#  'BIDSIZ',
#  'ASK',
#  'ASKSIZ',
#  'QU_COND',
#  'QU_SEQNUM',
#  'NATBBO_IND',
#  'QU_CANCEL',
#  'QU_SOURCE',
#  'SYM_ROOT',
#  'SYM_SUFFIX',
#  'MID_PRICE',
#  'Volume',
#  'VWAP',
#  'OBI',
#  'Signal',
#  'Account_Balance']

# %%
# df_tmp = backtest_data.filter(pl.col("VWAP").is_not_null())

# %%
backtest_data['OBI'].describe()
# Out:
# shape: (2, 2)
# ┌────────────┬───────┐
# │ statistic  ┆ value │
# │ ---        ┆ ---   │
# │ str        ┆ f64   │
# ╞════════════╪═══════╡
# │ count      ┆ 0.0   │
# │ null_count ┆ 0.0   │
# └────────────┴───────┘

# %%
df_tmp = backtest_data.filter(pl.col("VWAP").is_not_null())
df_tmp
# Out:
# shape: (0, 20)
# ┌──────┬────────┬─────┬─────┬───┬──────┬─────┬────────┬─────────────────┐
# │ DATE ┆ TIME_M ┆ EX  ┆ BID ┆ … ┆ VWAP ┆ OBI ┆ Signal ┆ Account_Balance │
# │ ---  ┆ ---    ┆ --- ┆ --- ┆   ┆ ---  ┆ --- ┆ ---    ┆ ---             │
# │ str  ┆ time   ┆ str ┆ f64 ┆   ┆ f64  ┆ f64 ┆ i32    ┆ null            │
# ╞══════╪════════╪═════╪═════╪═══╪══════╪═════╪════════╪═════════════════╡
# └──────┴────────┴─────┴─────┴───┴──────┴─────┴────────┴─────────────────┘

# %%
df_tmp[['QU_SEQNUM', 'OBI']].head(1000).plot.line(x="QU_SEQNUM", y="OBI")
# Out:
# ---------------------------------------------------------------------------
# ModuleUpgradeRequiredError                Traceback (most recent call last)
# /var/folders/h2/r7qn2m9n1zb6y_0q191gdqth0000gn/T/ipykernel_15612/228775074.py in ?()
# ----> 1 df_tmp[['QU_SEQNUM', 'OBI']].head(1000).plot.line(x="QU_SEQNUM", y="OBI")
#
# ~/Projects/00_SMU/mqf_practice/.conda/lib/python3.11/site-packages/polars/_utils/unstable.py in ?(*args, **kwargs)
#      55         @wraps(function)
#      56         def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      57             issue_unstable_warning(f"`{function.__name__}` is considered unstable.")
# ---> 58             return function(*args, **kwargs)
#
# ~/Projects/00_SMU/mqf_practice/.conda/lib/python3.11/site-packages/polars/dataframe/frame.py in ?(self)
#     711         >>> df.plot.bar(x="day", y="value", color="group")  # doctest: +SKIP
#     712         """
#     713         if not _ALTAIR_AVAILABLE or parse_version(altair.__version__) < (5, 4, 0):
#     714             msg = "altair>=5.4.0 is required for `.plot`"
# --> 715             raise ModuleUpgradeRequiredError(msg)
#     716         return DataFramePlot(self)
#
# ModuleUpgradeRequiredError: altair>=5.4.0 is required for `.plot`

# %%
df_tmp[['QU_SEQNUM', 'MID_PRICE']].head(1000).plot.line(x="QU_SEQNUM", y="MID_PRICE")
# Out:
# alt.Chart(...)

# %%
df_tmp[['QU_SEQNUM', 'VWAP']].head(1000).plot.line(x="QU_SEQNUM", y="VWAP")
# Out:
# alt.Chart(...)

# %%
df_tmp.head(100).to_pandas().plot.line(x="QU_SEQNUM", y="OBI")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_tmp.head(100).to_pandas().plot.line(x="QU_SEQNUM", y="OBI")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/dataframe/frame.py:2443, in DataFrame.to_pandas(self, use_pyarrow_extension_array, **kwargs)
#    2438 if Object in self.dtypes:
#    2439     return self._to_pandas_with_object_columns(
#    2440         use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2441     )
# -> 2443 return self._to_pandas_without_object_columns(
#    2444     self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2445 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/dataframe/frame.py:2505, in DataFrame._to_pandas_without_object_columns(self, df, use_pyarrow_extension_array, **kwargs)
#    2497     return tbl.to_pandas(
#    2498         self_destruct=True,
#    2499         split_blocks=True,
#    2500         types_mapper=lambda pa_dtype: pd.ArrowDtype(pa_dtype),
#    2501         **kwargs,
#    2502     )
#    2504 date_as_object = kwargs.pop("date_as_object", False)
# -> 2505 return tbl.to_pandas(date_as_object=date_as_object, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyarrow/array.pxi:987, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyarrow/table.pxi:5174, in pyarrow.lib.Table._to_pandas()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyarrow/pandas_compat.py:808, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     805 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     807 column_names = table.column_names
# --> 808 result = pa.lib.table_to_blocks(options, table, categories,
#     809                                 list(ext_columns_dtypes.keys()))
#     810 if _pandas_api.is_ge_v3():
#     811     from pandas.api.internals import create_dataframe_from_blocks
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyarrow/table.pxi:4103, in pyarrow.lib.table_to_blocks()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Value 37800048115245 has non-zero nanoseconds

# %%
df_tmp.head(2000).plot.line(x="TIME_M", y="MID_PRICE")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:554, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:554, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/schema/channels.py:193, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     191 elif isinstance(shorthand, str):
#     192     data: nw.DataFrame | Any = context.get("data", None)
# --> 193     parsed = parse_shorthand(shorthand, data=data)
#     194     type_required = "type" in self._kwds  # type: ignore[attr-defined]
#     195     type_in_shorthand = "type" in parsed
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/core.py:680, in parse_shorthand(shorthand, data, parse_aggregates, parse_window_ops, parse_timeunits, parse_types)
#     678     attrs["type"] = infer_vegalite_type_for_pandas(column.to_native())
#     679 else:
# --> 680     attrs["type"] = infer_vegalite_type_for_narwhals(column)
#     681 if isinstance(attrs["type"], tuple):
#     682     attrs["sort"] = attrs["type"][1]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/core.py:724, in infer_vegalite_type_for_narwhals(column)
#     722 else:
#     723     msg = f"Unexpected DtypeKind: {dtype}"
# --> 724     raise ValueError(msg)
#
# ValueError: Unexpected DtypeKind: Time
# alt.Chart(...)

# %%
df_tmp.head(2000).plot.line(x="TIME_M", y="OBI")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:554, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:554, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/vegalite/v5/schema/channels.py:193, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     191 elif isinstance(shorthand, str):
#     192     data: nw.DataFrame | Any = context.get("data", None)
# --> 193     parsed = parse_shorthand(shorthand, data=data)
#     194     type_required = "type" in self._kwds  # type: ignore[attr-defined]
#     195     type_in_shorthand = "type" in parsed
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/core.py:680, in parse_shorthand(shorthand, data, parse_aggregates, parse_window_ops, parse_timeunits, parse_types)
#     678     attrs["type"] = infer_vegalite_type_for_pandas(column.to_native())
#     679 else:
# --> 680     attrs["type"] = infer_vegalite_type_for_narwhals(column)
#     681 if isinstance(attrs["type"], tuple):
#     682     attrs["sort"] = attrs["type"][1]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/altair/utils/core.py:724, in infer_vegalite_type_for_narwhals(column)
#     722 else:
#     723     msg = f"Unexpected DtypeKind: {dtype}"
# --> 724     raise ValueError(msg)
#
# ValueError: Unexpected DtypeKind: Time
# alt.Chart(...)

# %%
df_tmp.head(2000).
# Out:
#   Cell In[25], line 1
#     df_tmp.head(2000).
#                       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Convert to pandas
backtest_data = backtest_data.with_columns(
    (pl.col("DATE").cast(pl.Utf8) + " " + pl.col("TIME_M").cast(pl.Utf8))
    .str.strptime(pl.Datetime("ns"), format="%Y-%m-%d %H:%M:%S%.f")
    .alias("TIME_M")
)

pdf = backtest_data.to_pandas()


# Plot
for ticker in set(pdf['SYM_ROOT']):
    ticker_df = pdf[pdf['SYM_ROOT'] == ticker]
    plt.figure(figsize=(12, 6))
    plt.plot(ticker_df["TIME_M"], ticker_df["Account_Balance"])
    plt.xlabel("TIME_M")
    plt.ylabel("Account_Balance")
    plt.title(f"Account Balance for {ticker}")
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvalidOperationError                     Traceback (most recent call last)
# Cell In[34], line 5
#       2 import matplotlib.dates as mdates
#       4 # Convert to pandas
# ----> 5 backtest_data = backtest_data.with_columns(
#       6     (pl.col("DATE").cast(pl.Utf8) + " " + pl.col("TIME_M").cast(pl.Utf8))
#       7     .str.strptime(pl.Datetime("ns"), format="%Y-%m-%d %H:%M:%S%.f")
#       8     .alias("TIME_M")
#       9 )
#      11 pdf = backtest_data.to_pandas()
#      14 # Plot
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/dataframe/frame.py:9830, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9684 def with_columns(
#    9685     self,
#    9686     *exprs: IntoExpr | Iterable[IntoExpr],
#    9687     **named_exprs: IntoExpr,
#    9688 ) -> DataFrame:
#    9689     """
#    9690     Add columns to this DataFrame.
#    9691
#    (...)
#    9828     └─────┴──────┴─────────────┘
#    9829     """
# -> 9830     return self.lazy().with_columns(*exprs, **named_exprs).collect(_eager=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/_utils/deprecation.py:93, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      89         kwargs["engine"] = "in-memory"
#      91     del kwargs["streaming"]
# ---> 93 return function(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/polars/lazyframe/frame.py:2224, in LazyFrame.collect(self, type_coercion, _type_check, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, _check_order, _eager, **_kwargs)
#    2222 # Only for testing purposes
#    2223 callback = _kwargs.get("post_opt_callback", callback)
# -> 2224 return wrap_df(ldf.collect(engine, callback))
#
# InvalidOperationError: conversion from `str` to `datetime[ns]` failed in column 'DATE' for 346766 out of 346766 values: ["2023-05-11 2023-05-11 10:30:00.000000000", "2023-05-11 2023-05-11 10:30:00.000000000", … "2023-05-11 2023-05-11 11:59:59.000000000"]
#
# You might want to try:
# - setting `strict=False` to set values that cannot be converted to `null`
# - using `str.strptime`, `str.to_date`, or `str.to_datetime` and providing a format string
